# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.20.3

# %%
df=pd.read_csv(r'C:\Users\RG\Downloads\gapminder.csv')
df
# Out:
#      population  fertility   HIV       CO2  BMI_male      GDP  BMI_female  \
# 134   3350832.0       2.11   0.5  2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1  4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4  1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6  0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1  0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality                 Region
# 134  76.0             13.0                America
# 135  68.7             49.2  Europe & Central Asia
# 136  75.4             26.2    East Asia & Pacific
# 137  52.0             94.9     Sub-Saharan Africa
# 138  49.0             98.3     Sub-Saharan Africa

# %%
df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0  34811059.0       2.73  0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1  19842251.0       6.43  2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2  40381860.0       2.24  0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3   2975029.0       1.40  0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4  21370348.0       1.96  0.1  18.016313  27.56373  41312.0    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
df.tail()
# Out:
#      population  fertility   HIV       CO2  BMI_male      GDP  BMI_female  \
# 134   3350832.0       2.11   0.5  2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1  4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4  1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6  0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1  0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality                 Region
# 134  76.0             13.0                America
# 135  68.7             49.2  Europe & Central Asia
# 136  75.4             26.2    East Asia & Pacific
# 137  52.0             94.9     Sub-Saharan Africa
# 138  49.0             98.3     Sub-Saharan Africa

# %%
 df.info()  #The shape attribute of pandas.DataFrame stores the number of rows and columns as a tuple 
# (number of rows, number of columns) .
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 10 columns):
# population         139 non-null float64
# fertility          139 non-null float64
# HIV                139 non-null float64
# CO2                139 non-null float64
# BMI_male           139 non-null float64
# GDP                139 non-null float64
# BMI_female         139 non-null float64
# life               139 non-null float64
# child_mortality    139 non-null float64
# Region             139 non-null object
# dtypes: float64(9), object(1)
# memory usage: 10.9+ KB

# %%
df.shape   #139 rows and 10 columns  
# The shape attribute of pandas.DataFrame stores the number of rows and columns as a tuple 
# (number of rows, number of columns).
# Out:
# (139, 10)

# %%
df.columns  # output name of columns
# Out:
# Index(['population', 'fertility', 'HIV', 'CO2', 'BMI_male', 'GDP',
#        'BMI_female', 'life', 'child_mortality', 'Region'],
#       dtype='object')

# %%
df.describe()  #describe() function computes a summary of statistics pertaining to the DataFrame columns. 
# This function gives the mean, std and IQR values. And, function excludes the character columns and given summary 
# about numeric columns.
# Out:
#          population   fertility         HIV         CO2    BMI_male  \
# count  1.390000e+02  139.000000  139.000000  139.000000  139.000000
# mean   3.549977e+07    3.005108    1.915612    4.459874   24.623054
# std    1.095121e+08    1.615354    4.408974    6.268349    2.209368
# min    2.773150e+05    1.280000    0.060000    0.008618   20.397420
# 25%    3.752776e+06    1.810000    0.100000    0.496190   22.448135
# 50%    9.705130e+06    2.410000    0.400000    2.223796   25.156990
# 75%    2.791973e+07    4.095000    1.300000    6.589156   26.497575
# max    1.197070e+09    7.590000   25.900000   48.702062   28.456980
#
#                  GDP  BMI_female        life  child_mortality
# count     139.000000  139.000000  139.000000       139.000000
# mean    16638.784173  126.701914   69.602878        45.097122
# std     19207.299083    4.471997    9.122189        45.724667
# min       588.000000  117.375500   45.200000         2.700000
# ...

# %%
df.rename(columns= {'population': 'pop'}, inplace = True)    #inplace =True will store the new output dataframe into the original
#variable df

# %%
df
# Out:
#              pop  fertility    HIV        CO2  BMI_male      GDP  BMI_female  \
# 0     34811059.0       2.73   0.10   3.328945  24.59620  12314.0    129.9049
# 1     19842251.0       6.43   2.00   1.474353  22.25083   7103.0    130.1247
# 2     40381860.0       2.24   0.50   4.785170  27.50170  14646.0    118.8915
# 3      2975029.0       1.40   0.10   1.804106  25.35542   7383.0    132.8108
# 4     21370348.0       1.96   0.10  18.016313  27.56373  41312.0    117.3755
# 5      8331465.0       1.41   0.30   8.183160  26.46741  43952.0    124.1394
# 6      8868713.0       1.99   0.10   5.109538  25.65117  14365.0    128.6024
# 7       348587.0       1.89   3.10   3.131921  27.24594  24373.0    124.3862
# 8    148252473.0       2.38   0.06   0.319161  20.39742   2265.0    125.0307
# 9       277315.0       1.83   1.30   6.008279  26.38439  16075.0    126.3940
# 10     9526453.0       1.42   0.20   6.488174  26.16443  14488.0    129.7968
# ...

# %%
import numpy as np
df.replace("Middle East & North Africa", np.NaN, inplace=False)
#replace "Middle East & North Africa" value by NaN; you can replace by any other value
# Out:
#              pop  fertility    HIV        CO2  BMI_male      GDP  BMI_female  \
# 0     34811059.0       2.73   0.10   3.328945  24.59620  12314.0    129.9049
# 1     19842251.0       6.43   2.00   1.474353  22.25083   7103.0    130.1247
# 2     40381860.0       2.24   0.50   4.785170  27.50170  14646.0    118.8915
# 3      2975029.0       1.40   0.10   1.804106  25.35542   7383.0    132.8108
# 4     21370348.0       1.96   0.10  18.016313  27.56373  41312.0    117.3755
# 5      8331465.0       1.41   0.30   8.183160  26.46741  43952.0    124.1394
# 6      8868713.0       1.99   0.10   5.109538  25.65117  14365.0    128.6024
# 7       348587.0       1.89   3.10   3.131921  27.24594  24373.0    124.3862
# 8    148252473.0       2.38   0.06   0.319161  20.39742   2265.0    125.0307
# 9       277315.0       1.83   1.30   6.008279  26.38439  16075.0    126.3940
# 10     9526453.0       1.42   0.20   6.488174  26.16443  14488.0    129.7968
# ...

# %%
df.isnull().sum()
# Out:
# pop                 0
# fertility           0
# HIV                 0
# CO2                 0
# BMI_male            0
# GDP                 0
# BMI_female          0
# life                0
# child_mortality     0
# Region             10
# dtype: int64

# %%
df
#NaN = Not an Number; if it has different data type such as string then its NaN which is also no data for numpy
# Out:
#              pop  fertility    HIV        CO2  BMI_male      GDP  BMI_female  \
# 0     34811059.0       2.73   0.10   3.328945  24.59620  12314.0    129.9049
# 1     19842251.0       6.43   2.00   1.474353  22.25083   7103.0    130.1247
# 2     40381860.0       2.24   0.50   4.785170  27.50170  14646.0    118.8915
# 3      2975029.0       1.40   0.10   1.804106  25.35542   7383.0    132.8108
# 4     21370348.0       1.96   0.10  18.016313  27.56373  41312.0    117.3755
# 5      8331465.0       1.41   0.30   8.183160  26.46741  43952.0    124.1394
# 6      8868713.0       1.99   0.10   5.109538  25.65117  14365.0    128.6024
# 7       348587.0       1.89   3.10   3.131921  27.24594  24373.0    124.3862
# 8    148252473.0       2.38   0.06   0.319161  20.39742   2265.0    125.0307
# 9       277315.0       1.83   1.30   6.008279  26.38439  16075.0    126.3940
# 10     9526453.0       1.42   0.20   6.488174  26.16443  14488.0    129.7968
# ...

# %%
df.dropna() # dropna() drops null value/NaN value in the df
# Out:
#              pop  fertility    HIV        CO2  BMI_male      GDP  BMI_female  \
# 1     19842251.0       6.43   2.00   1.474353  22.25083   7103.0    130.1247
# 2     40381860.0       2.24   0.50   4.785170  27.50170  14646.0    118.8915
# 3      2975029.0       1.40   0.10   1.804106  25.35542   7383.0    132.8108
# 4     21370348.0       1.96   0.10  18.016313  27.56373  41312.0    117.3755
# 5      8331465.0       1.41   0.30   8.183160  26.46741  43952.0    124.1394
# 6      8868713.0       1.99   0.10   5.109538  25.65117  14365.0    128.6024
# 7       348587.0       1.89   3.10   3.131921  27.24594  24373.0    124.3862
# 8    148252473.0       2.38   0.06   0.319161  20.39742   2265.0    125.0307
# 9       277315.0       1.83   1.30   6.008279  26.38439  16075.0    126.3940
# 10     9526453.0       1.42   0.20   6.488174  26.16443  14488.0    129.7968
# 11    10779155.0       1.82   0.20   9.797337  26.75915  41641.0    121.8227
# ...

# %%
df.fillna('Middle East  & North Rajan Africa') #The fillna() method returns a new DataFrame object unless the inplace parameter is set to True, in that case the fillna() method does
#the replacing in the original DataFrame instead.
#dataframe.fillna(value, method, axis, inplace, limit, downcast)
# Out:
#              pop  fertility    HIV        CO2  BMI_male      GDP  BMI_female  \
# 0     34811059.0       2.73   0.10   3.328945  24.59620  12314.0    129.9049
# 1     19842251.0       6.43   2.00   1.474353  22.25083   7103.0    130.1247
# 2     40381860.0       2.24   0.50   4.785170  27.50170  14646.0    118.8915
# 3      2975029.0       1.40   0.10   1.804106  25.35542   7383.0    132.8108
# 4     21370348.0       1.96   0.10  18.016313  27.56373  41312.0    117.3755
# 5      8331465.0       1.41   0.30   8.183160  26.46741  43952.0    124.1394
# 6      8868713.0       1.99   0.10   5.109538  25.65117  14365.0    128.6024
# 7       348587.0       1.89   3.10   3.131921  27.24594  24373.0    124.3862
# 8    148252473.0       2.38   0.06   0.319161  20.39742   2265.0    125.0307
# 9       277315.0       1.83   1.30   6.008279  26.38439  16075.0    126.3940
# 10     9526453.0       1.42   0.20   6.488174  26.16443  14488.0    129.7968
# ...

# %%
df.isnull().sum()   #so isna() summs if there is empty cols
# Out:
# pop                 0
# fertility           0
# HIV                 0
# CO2                 0
# BMI_male            0
# GDP                 0
# BMI_female          0
# life                0
# child_mortality     0
# Region             10
# dtype: int64

# %%
$ jupyter nbextension install codehighlighter.js --user
$ jupyter nbextension enable codehighlighter --user
# Out:
#   File "<ipython-input-32-f02f7550e071>", line 1
#     $ jupyter nbextension install codehighlighter.js --user
#     ^
# SyntaxError: invalid syntax
